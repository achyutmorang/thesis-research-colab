# %% [markdown]
# # Paper Experiment Template (Colab)
#
# ## Objective
# - Replicate and extend one paper idea on Waymax/WOMD.
# - Keep notebook orchestration-only; put reusable logic in `src/`.
# - Persist checkpoints and artifacts to Drive for runtime interruption recovery.

# %% [markdown]
# ## Expected Outputs
# - Run manifest (`run_manifest.json`)
# - Per-scenario metrics CSV
# - Diagnostics summary CSV
# - Exported plots/tables for reporting

# %%
# Step 1: Bootstrap (repo sync + deterministic env setup)
# Keep this cell idempotent.
REPO_URL = "https://github.com/achyutmorang/waymax-simulation-experiments.git"
REPO_DIR = "/content/waymax-simulation-experiments"
print("Set repo bootstrap logic here")

# %%
# Step 2: Imports + pack config
from src.workflows import bootstrap_experiment_pack

bundle = bootstrap_experiment_pack(slug="closedloop-simulation", repo_root=".")
display(bundle.summary_df)

# %%
# Step 3: Fast-fail probe (small budget)
print("Run quick diagnostic probe here before full execution.")

# %%
# Step 4: Main run (resumable)
print("Run main experiment loop here.")

# %%
# Step 5: Evaluation + export
print("Export metrics/artifacts and persist manifests here.")
